# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import OrderedDict
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.font_manager as font_manager

# %%
linestyles = OrderedDict(
    [('solid',               (0, ())),
     ('loosely dotted',      (0, (1, 10))),
     ('dotted',              (0, (1, 5))),
     ('densely dotted',      (0, (1, 1))),

     ('loosely dashed',      (0, (5, 10))),
     ('dashed',              (0, (5, 5))),
     ('densely dashed',      (0, (5, 1))),

     ('loosely dashdotted',  (0, (3, 10, 1, 10))),
     ('dashdotted',          (0, (3, 5, 1, 5))),
     ('densely dashdotted',  (0, (3, 1, 1, 1))),

     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))])

# %%
#COCO
x1= np.array([[1.78,3.68,5.16,8.04,15.67],[2.93,8.11,12.72,21.81,43.57],[9.66,15.79,19.22,23.86,29.82],
             [33.99,47.31,53.50,62.80,74.40]]) #1, 2, 3, 6
x2 = np.array([[36.61,52.14,59.10,67.45], [36.53,51.92,58.66,65.35]]) # 4, 5
x3 = np.array([[48.93,65.24,70.52,72.76,72.76], [45.34,58.68,62.15,64.68,64.79], [46.81,61.13,65.03,67.92,70.51],]) #7, 8

# %%
labels = ["10", "30", "50", "100", "300"] 

#COCO
x1= np.array([[1.78,3.68,5.16,8.04,15.67],[2.93,8.11,12.72,21.81,43.57],[9.66,15.79,19.22,23.86,29.82],
             [33.99,47.31,53.50,62.80,74.40]]) #1, 2, 3, 6
x2 = np.array([[36.61,52.14,59.10,67.45], [36.53,51.92,58.66,65.35]]) # 4, 5
x3 = np.array([[48.93,65.24,70.52,72.76], [45.34,58.68,62.15,64.68], [46.81,61.13,65.03,67.92]]) 

fig, (a1, a2) = plt.subplots(1,2, figsize=(7,2.3), dpi=450)
s = 4.0
l = 1.8
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]

# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
a1.plot(x1[0].T,c='brown',marker=">",ls=lstyle,label='Edge Boxes', markersize=s,linewidth=l)
a1.plot(x1[1].T,c='c',marker="p",ls=lstyle,label='Selective Search', markersize=s,linewidth=l)
a1.plot(x1[2].T,c='forestgreen',marker="X",ls=lstyle,label='Deep Mask', markersize=s,linewidth=l)
lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
a1.plot(x2[0].T,c='tomato',marker="d",ls=lstyle,label='RetinaNet', markersize=s,linewidth=l)
a1.plot(x2[1].T,c='steelblue',marker="P",ls=lstyle,label='Faster-RCNN', markersize=s,linewidth=l)
a1.plot(x1[3].T,c='purple',marker="h",ls=lstyle,label='Deformable-DETR', markersize=s,linewidth=l)
lstyle = "dashed"
a1.plot(x3[0].T,c='mediumvioletred',marker="*",ls=lstyle,label='GPV-I', markersize=s,linewidth=l)
a1.plot(x3[1].T,c='y',marker="8",ls=lstyle,label='MDETR-R101', markersize=s,linewidth=l)
a1.plot(x3[2].T,c='indigo',marker="8",ls=lstyle,label='MDef-DETR', markersize=s,linewidth=l)

a1.set_xticks([0, 1, 2, 3, 4])
a1.set_xticklabels(labels, fontsize=10, fontweight='bold')
a1.set_ylabel("Recall 50", fontsize=12, fontweight='bold')
a1.set_xlabel("MS COCO",fontsize=10, fontweight='bold')
a1.yaxis.set_tick_params(labelsize=7)

a1.grid(True, which='major', color='gray', linestyle='-', alpha=0.4)
a1.grid(True, which='minor', color='gray', linestyle='--', alpha=0.1)
a1.minorticks_on()


# KITTI
x1= np.array([[2.47,4.93,6.58,9.67,17.13],[1.02,2.96,4.85,9.37,23.38],[7.78,12.94,15.50,18.41,20.45],
             [36.56,49.48,55.00,61.46,66.88]]) #1, 2, 3, 6
x2 = np.array([[39.68,51.87,57.60,64.85], [35.31,47.51,53.23,60.86]]) # 4, 5
x3 = np.array([[51.71,61.64,64.43,67.73], [52.52,63.58,67.24,70.84], [55.38,62.10,63.53,65.39]]) #7, 8

labels = ["10", "30", "50", "100", "300"]  
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
lstyle = "dashed"
# lstyle = "solid"
a2.plot(x1[0].T,c='brown',marker=">",ls=lstyle,label='Edge Boxes', markersize=s,linewidth=l)
a2.plot(x1[1].T,c='c',marker="p",ls=lstyle,label='SS', markersize=s,linewidth=l)
a2.plot(x1[2].T,c='forestgreen',marker="X",ls=lstyle,label='Deep Mask', markersize=s,linewidth=l)
lstyle = linestyles['dotted']
lstyle = "dashed"
a2.plot(x2[0].T,c='tomato',marker="d",ls=lstyle,label='RetinaNet', markersize=s,linewidth=l)
a2.plot(x2[1].T,c='steelblue',marker="P",ls=lstyle,label='Faster-RCNN', markersize=s,linewidth=l)
a2.plot(x1[3].T,c='purple',marker="h",ls=lstyle,label='Def-DETR', markersize=s,linewidth=l)
lstyle = "dashed"
a2.plot(x3[0].T,c='mediumvioletred',marker="*",ls=lstyle,label='GPV-I', markersize=s,linewidth=l)
a2.plot(x3[1].T,c='y',marker="8",ls=lstyle,label='MDETR', markersize=s,linewidth=l)
a2.plot(x3[2].T,c='indigo',marker="8",ls=lstyle,label='MDef-DETR', markersize=s,linewidth=l)

a2.set_xticks([0, 1, 2, 3, 4])
a2.set_xticklabels(labels, fontsize=9, fontweight='bold')
# a2.set_ylabel("Recall 50", fontsize=12, fontweight='bold')
a2.set_xlabel("KITTI",fontsize=10, fontweight='bold')
a2.yaxis.set_tick_params(labelsize=7)

a2.grid(True, which='major', color='gray', linestyle='-', alpha=0.4)
a2.grid(True, which='minor', color='gray', linestyle='--', alpha=0.1)
a2.minorticks_on()
font = font_manager.FontProperties(family= 'Comic Sans MS',  # 'Times new roman', 
                                   weight='bold',
                                   style='normal', size=10)
handles, labels = a2.get_legend_handles_labels()
# lgd = fig.legend(handles, labels, loc='upper center',  bbox_to_anchor=(0.485, 1.1), 
#                  borderaxespad=0.01, ncol=5, prop=font, handletextpad=0.1, handlelength=1.5,columnspacing=0.8)
plt.subplots_adjust(wspace=0.11, hspace=0.0)
plt.show()
# fig.savefig('graph_1.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)

# %%
labels = ["10", "30", "50", "100", "300"] 

#COCO
# Lets create graph for showing effect of context vector
ablation_ctx_vectors_hm = [77.77,
78.55,
78.16,
76.52,
76.84,
75.12,
77.73,
75.55,
75.23]

ablation_ctx_vectors_base = [81.61,
82.28,
82.53,
81.40,
82.11,
81.60,
82.39,
81.97,
81.15]

ablation_ctx_vectors_new = [74.28,
75.14,
74.23,
72.20,
72.20,
69.60,
73.58,
70.06,
70.11]


labels = ["1 CTX", "2 CTX",  "3 CTX", "4 CTX",  "5 CTX", "6 CTX", "8 CTX", "10 CTX","16 CTX"]
x1= np.array([[1.78,3.68,5.16,8.04,15.67],[2.93,8.11,12.72,21.81,43.57],[9.66,15.79,19.22,23.86,29.82],
             [33.99,47.31,53.50,62.80,74.40]]) #1, 2, 3, 6
x2 = np.array([[36.61,52.14,59.10,67.45], [36.53,51.92,58.66,65.35]]) # 4, 5
x3 = np.array([[48.93,65.24,70.52,72.76], [45.34,58.68,62.15,64.68], [46.81,61.13,65.03,67.92]]) 

fig, (a1, a2) = plt.subplots(1,2, figsize=(7,2.3), dpi=450)
s = 4.0
l = 1.8
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]

# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
a1.plot(ablation_ctx_vectors_hm,c='brown',marker=">",ls=lstyle,label='H.M', markersize=s,linewidth=l)
a1.plot(ablation_ctx_vectors_base,c='c',marker="p",ls=lstyle,label='Base Acc.', markersize=s,linewidth=l)
a1.plot(ablation_ctx_vectors_new,c='forestgreen',marker="X",ls=lstyle,label='Novel Acc.', markersize=s,linewidth=l)
# lstyle = linestyles['densely dashdotdotted']
# lstyle = "dashed"
# a1.plot(ablation_ctx_vectors_base,c='tomato',marker="d",ls=lstyle,label='RetinaNet', markersize=s,linewidth=l)
# a1.plot(ablation_ctx_vectors_new,c='steelblue',marker="P",ls=lstyle,label='Faster-RCNN', markersize=s,linewidth=l)
# a1.plot(x1[3].T,c='purple',marker="h",ls=lstyle,label='Deformable-DETR', markersize=s,linewidth=l)
# lstyle = "dashed"
# a1.plot(x3[0].T,c='mediumvioletred',marker="*",ls=lstyle,label='GPV-I', markersize=s,linewidth=l)
# a1.plot(x3[1].T,c='y',marker="8",ls=lstyle,label='MDETR-R101', markersize=s,linewidth=l)
# a1.plot(x3[2].T,c='indigo',marker="8",ls=lstyle,label='MDef-DETR', markersize=s,linewidth=l)

# a1.set_xticks([1, 2, 3, 4, 5, 6 ,8 ,10, 16])
a1.set_xticklabels(labels, fontsize=10, fontweight='bold')
a1.set_ylabel("Recall 50", fontsize=12, fontweight='bold')
a1.set_xlabel("MS COCO",fontsize=10, fontweight='bold')
a1.yaxis.set_tick_params(labelsize=9)

a1.grid(True, which='major', color='gray', linestyle='-', alpha=0.4)
a1.grid(True, which='minor', color='gray', linestyle='--', alpha=0.1)
a1.minorticks_on()
plt.subplots_adjust(wspace=0.11, hspace=0.0)
plt.show()

# # KITTI
# x1= np.array([[2.47,4.93,6.58,9.67,17.13],[1.02,2.96,4.85,9.37,23.38],[7.78,12.94,15.50,18.41,20.45],
#              [36.56,49.48,55.00,61.46,66.88]]) #1, 2, 3, 6
# x2 = np.array([[39.68,51.87,57.60,64.85], [35.31,47.51,53.23,60.86]]) # 4, 5
# x3 = np.array([[51.71,61.64,64.43,67.73], [52.52,63.58,67.24,70.84], [55.38,62.10,63.53,65.39]]) #7, 8

# labels = ["10", "30", "50", "100", "300"]  
# c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
# lstyle = "dashed"
# # lstyle = "solid"
# a2.plot(x1[0].T,c='brown',marker=">",ls=lstyle,label='Edge Boxes', markersize=s,linewidth=l)
# a2.plot(x1[1].T,c='c',marker="p",ls=lstyle,label='SS', markersize=s,linewidth=l)
# a2.plot(x1[2].T,c='forestgreen',marker="X",ls=lstyle,label='Deep Mask', markersize=s,linewidth=l)
# lstyle = linestyles['dotted']
# lstyle = "dashed"
# a2.plot(x2[0].T,c='tomato',marker="d",ls=lstyle,label='RetinaNet', markersize=s,linewidth=l)
# a2.plot(x2[1].T,c='steelblue',marker="P",ls=lstyle,label='Faster-RCNN', markersize=s,linewidth=l)
# a2.plot(x1[3].T,c='purple',marker="h",ls=lstyle,label='Def-DETR', markersize=s,linewidth=l)
# lstyle = "dashed"
# a2.plot(x3[0].T,c='mediumvioletred',marker="*",ls=lstyle,label='GPV-I', markersize=s,linewidth=l)
# a2.plot(x3[1].T,c='y',marker="8",ls=lstyle,label='MDETR', markersize=s,linewidth=l)
# a2.plot(x3[2].T,c='indigo',marker="8",ls=lstyle,label='MDef-DETR', markersize=s,linewidth=l)

# a2.set_xticks([0, 1, 2, 3, 4])
# a2.set_xticklabels(labels, fontsize=9, fontweight='bold')
# # a2.set_ylabel("Recall 50", fontsize=12, fontweight='bold')
# a2.set_xlabel("KITTI",fontsize=10, fontweight='bold')
# a2.yaxis.set_tick_params(labelsize=7)

# a2.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.4)
# a2.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.1)
# a2.minorticks_on()
# font = font_manager.FontProperties(family= 'Comic Sans MS',  # 'Times new roman', 
#                                    weight='bold',
#                                    style='normal', size=10)
# handles, labels = a2.get_legend_handles_labels()
# # lgd = fig.legend(handles, labels, loc='upper center',  bbox_to_anchor=(0.485, 1.1), 
# #                  borderaxespad=0.01, ncol=5, prop=font, handletextpad=0.1, handlelength=1.5,columnspacing=0.8)
# plt.subplots_adjust(wspace=0.11, hspace=0.0)
# plt.show()
# fig.savefig('graph_1.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_1292097/595785822.py:63: UserWarning: FixedFormatter should only be used together with FixedLocator
#   a1.set_xticklabels(labels, fontsize=10, fontweight='bold')

# %%
import pandas as pd
# Lets create graph for showing effect of context vector
ablation_ctx_vectors_hm = [76.97,
77.86,
78.43,
77.15,
77.24,
74.66,
77.87,
75.31,
75.02]

ablation_ctx_vectors_base = [80.88,
82.14,
82.17,
81.58,
82.58,
81.43,
82.23,
81.63,
80.68]

ablation_ctx_vectors_new = [73.41,
74.00,
75.02,
73.18,
72.55,
68.93,
73.94,
69.90,
70.09]


labels = ["1 CTX", "2 CTX",  "3 CTX", "4 CTX",  "5 CTX", "6 CTX", "8 CTX", "10 CTX","16 CTX"]

# Need to make dataframe
data = {'ablation_base':ablation_ctx_vectors_base, 'ablation_new':ablation_ctx_vectors_new, 'ablation_hm': ablation_ctx_vectors_hm}
df = pd.DataFrame(data)

# %%
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig = plt.figure(figsize=(10,6), dpi=450)
ax=fig.add_subplot(111)
s = 7
l = 3.5
c = ["brown", "steelblue", "indigo", "c", "tomato", "purple", "mediumvioletred", "y"]

# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashdot"
ax.plot(ablation_ctx_vectors_base,c='c',marker="p",ls=lstyle,label='Base Acc.', markersize=s,linewidth=l)
ax.plot(ablation_ctx_vectors_hm,c='firebrick',marker=">",ls=lstyle,label='H.M', markersize=s,linewidth=l)
ax.plot(ablation_ctx_vectors_new,c='forestgreen',marker="X",ls=lstyle,label='Novel Acc.', markersize=s,linewidth=l)
labels = ["1", "1", "2",  "3", "4",  "5", "6", "8", "10","16"]
ax.set_xticklabels(labels, fontsize=14, fontweight='bold')
ax.set_ylabel("Performance %", fontsize=20, fontweight='bold')
ax.set_xlabel("# Prompt tokens",fontsize=20, fontweight='bold')
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=14,  weight='bold')
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
plt.legend(fontsize=19, labels=['Base Acc.', 'H.M', 'Novel Acc.'], borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
# # plt.savefig("prompt_length_ablation.png",dpi=500)
# plt.show()
fig.savefig('graph_1.png', dpi=250, facecolor='auto', edgecolor='auto',
            orientation='portrait', format="png",
            transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_1292097/2338965566.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=14, fontweight='bold')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 19
#      17 ax.yaxis.set_tick_params(labelsize=9)
#      18 plt.yticks(fontsize=14,  weight='bold')
# ---> 19 ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
#      20 ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
#      21 ax.minorticks_on()
#
# File ~/.conda/envs/maple/lib/python3.8/site-packages/matplotlib/axes/_base.py:3194, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3192 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3193 if axis in ['x', 'both']:
# -> 3194     self.xaxis.grid(visible, which=which, **kwargs)
#    3195 if axis in ['y', 'both']:
# ...

# %%
# Now plotting the depth ablation graph
only_visual = [70.06,
71.50,
73.45,
74.82,
75.53,
76.93]

only_textual = [75.56,
75.98,
76.99,
76.67,
75.57,
77.45]

# both_VPTP = [74.59,
# 75.49,
# 76.19,
# 77.46,
# 77.88,
# 76.70 ]


both_VPTP = [74.38,
76.38,
77.31,
77.35,
77.14,
77.53]
layers = ["layers 1", "layers 1", "layers 1-3", "layers 1-5", "layers 1-7", "layers 1-9", "layers 1-12"]

compound_prompting = [74.71,
76.43,
76.52,
77.91,
78.00,
77.36]

# %%
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig = plt.figure(figsize=(10,6), dpi=450)
ax=fig.add_subplot(111)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(only_visual,marker="p",ls='dashdot',label='Vision prompting', markersize=8,linewidth=l)
ax.plot(only_textual,marker=">",ls='dashed',label='Language prompting', markersize=8,linewidth=l)
ax.plot(both_VPTP,marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
ax.plot(compound_prompting,marker="*",ls='solid',label='MaPLe', markersize=10,linewidth=l)
labels = layers
ax.set_xticklabels(labels, fontsize=14, fontweight='bold')
ax.set_ylabel("H.M %", fontsize=20, fontweight='bold')
ax.set_xlabel("# Layer depth",fontsize=20, fontweight='bold')
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=14,  weight='bold')
ax.grid(b=True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(b=True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
plt.legend(fontsize=19, labels=['Vision prompting', 'Language prompting', 'Naive V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
# # plt.savefig("prompt_length_ablation.png",dpi=500)
# plt.show()
fig.savefig('graph_2.png', dpi=250, facecolor='auto', edgecolor='auto',
            orientation='portrait', format="png",
            transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       8 # lstyle = linestyles['densely dashdotdotted']
#       9 lstyle = "dashed"
# ---> 10 ax.plot(only_visual,marker="p",ls='dashdot',label='Vision prompting', markersize=8,linewidth=l)
#      11 ax.plot(only_textual,marker=">",ls='dashed',label='Language prompting', markersize=8,linewidth=l)
#      12 ax.plot(both_VPTP,marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
#
# NameError: name 'only_visual' is not defined

# %%
beta_weights = [10, 50, 100, 150, 200]
beta_acc = [58.73, 59.24, 59.37, 59.39, 59.41]

n_views = [8, 16, 32, 64, 128]
pa_view_acc = [50.85, 57.61, 58.32, 59.14, 59.61]

tpt_steps_acc =[50.72, 56.39, 57.11, 58.08, 58.24]

# %%
linestyles = OrderedDict(
    [('solid',               (0, ())),
     ('loosely dotted',      (0, (1, 10))),
     ('dotted',              (0, (1, 5))),
     ('densely dotted',      (0, (1, 1))),

     ('loosely dashed',      (0, (5, 10))),
     ('dashed',              (0, (5, 5))),
     ('densely dashed',      (0, (5, 1))),

     ('loosely dashdotted',  (0, (3, 10, 1, 10))),
     ('dashdotted',          (0, (3, 5, 1, 5))),
     ('densely dashdotted',  (0, (3, 1, 1, 1))),

     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))])

# %%
# NOW SETTING THE TREND FOR CTX ABLATION STUDY
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig, ax = plt.subplots(figsize = (10,6), dpi=500)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(beta_weights, beta_acc,marker="p",ls='dashdot',label='PromptAlign', markersize=12,linewidth=l)
ax.plot([0], [58.08],marker="*",ls='dashed',label='MaPLe+TPT', markersize=15,linewidth=l, color=c[2])
# ax.plot(both_VPTP,marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
# ax.plot(compound_prompting,marker="*",ls='solid',label='MaPLe', markersize=10,linewidth=l)
labels = beta_weights
ax.set_xticklabels(labels, fontsize=23)

ax.set_ylabel("Top-1 average accuracy %", fontsize=26)
ax.set_xlabel("Weight scale factor β",fontsize=26)
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=23)
plt.xticks(labels)
ax.grid(True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
plt.xlim(-3,210)
plt.legend(fontsize=23, labels=['PromptAlign', 'MaPLe+TPT'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# plt.legend(fontsize=14, labels=['Vision prompting', 'Language prompting', 'Independent V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
plt.savefig("loss_scale.png",dpi=500, bbox_inches='tight')
# plt.show()
# fig.savefig('graph_2_optional.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_1001791/3226071037.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=23)

# %%
# NOW SETTING THE TREND FOR CTX ABLATION STUDY
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig = plt.figure(figsize=(10,6), dpi=500)
ax=fig.add_subplot(111)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
# c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(n_views, pa_view_acc, marker="X",ls='dashdot',label='PromptAlign', markersize=12,linewidth=l, color='#B43CC3')
ax.plot(n_views, tpt_view_acc, marker="*",ls='dashed',label='MaPLe+TPT', markersize=12,linewidth=l, color='#4BC33C')
# ax.plot(both_VPTP,marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
# ax.plot(compound_prompting,marker="*",ls='solid',label='MaPLe', markersize=10,linewidth=l)
labels = n_views
ax.set_xticklabels(labels, fontsize=23)
ax.set_ylabel("Top-1 average accuracy %", fontsize=26)
ax.set_xlabel("Number of augmented views\n (a)",fontsize=26)
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=23)
plt.xticks(n_views)
ax.grid(True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
plt.legend(fontsize=23, labels=['PromptAlign', 'MaPLe+TPT', 'Independent V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
plt.savefig("num_of_views.png",dpi=500, bbox_inches='tight')
# plt.show()
# fig.savefig('graph_2_optional.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_1304755/3521239645.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=23)

# %%
n_steps = [1, 2, 4, 6, 8]
tpt_steps_acc = [58.05,  60.78, 62.07, 62.36, 62.53]
pa_steps_acc = [59.37,  61.06, 62.27, 62.69, 62.77]

# %%
# NOW SETTING THE TREND FOR CTX ABLATION STUDY
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig = plt.figure(figsize=(10,6), dpi=500)
ax=fig.add_subplot(111)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
# c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(n_steps, pa_steps_acc, marker="X",ls='dashdot',label='PromptAlign', markersize=12, linewidth=l, color='#B43CC3')
ax.plot(n_steps, tpt_steps_acc, marker="X",ls='dashed',label='MaPLe+TPT', markersize=12, linewidth=l, color='#4BC33C')
# ax.plot(both_VPTP,marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
# ax.plot(compound_prompting,marker="*",ls='solid',label='MaPLe', markersize=10,linewidth=l)
labels = n_steps
ax.set_xticklabels(labels, fontsize=23)
ax.set_ylabel("Top-1 average accuracy %", fontsize=26)
ax.set_xlabel("Number of prompt update steps\n (b)",fontsize=26)
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=23)
plt.xticks(n_steps)
ax.grid(True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
plt.legend(fontsize=23, labels=['PromptAlign', 'MaPLe+TPT', 'Independent V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
plt.savefig("num_steps.png",dpi=500, bbox_inches='tight')
# plt.show()
# fig.savefig('graph_2_optional.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_1228160/733926014.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=23)

# %%
n_steps = [1, 2, 4, 6, 8]
pa_time = [0.45 , 0.94, 1.76, 2.59, 3.53]
tpt_time = [0.41, 1.04, 1.71, 2.57, 3.34]

# %%
# NOW SETTING THE TREND FOR CTX ABLATION STUDY
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig = plt.figure(figsize=(10,6), dpi=500)
ax=fig.add_subplot(111)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
# c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(n_steps, pa_time, marker="X",ls='dashdot',label='PromptAlign', markersize=12, linewidth=l, color='#B43CC3')
ax.plot(n_steps, tpt_time, marker="X",ls='dashed',label='MaPLe+TPT', markersize=12, linewidth=l, color='#4BC33C')
# ax.plot(both_VPTP,marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
# ax.plot(compound_prompting,marker="*",ls='solid',label='MaPLe', markersize=10,linewidth=l)
labels = n_steps
ax.set_xticklabels(labels, fontsize=23)
ax.set_ylabel("Time taken (in hours) ", fontsize=26)
ax.set_xlabel("Number of prompt update steps\n (c)",fontsize=26)
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=23)
plt.xticks(n_steps)
ax.grid(True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
plt.legend(fontsize=23, labels=['PromptAlign', 'MaPLe+TPT', 'Independent V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
plt.savefig("timing.png",dpi=500, bbox_inches='tight')
# plt.show()
# fig.savefig('graph_2_optional.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_1304755/1829812511.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=23)

# %%
beta_weights = [10, 50, 100, 150, 200]
beta_acc = [71.41, 71.55, 71.58, 71.59, 71.59]

# %%
# NOW SETTING THE TREND FOR CTX ABLATION STUDY
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig, ax = plt.subplots(figsize = (10,6), dpi=500)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(beta_weights, beta_acc,marker="p",ls='dashdot',label='PromptAlign', markersize=15,linewidth=l)
ax.plot([0], [71.25],marker="*",ls='dashed',label='MaPLe+TPT', markersize=15,linewidth=l, color=c[2])
# ax.plot(both_VPTP,marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
# ax.plot(compound_prompting,marker="*",ls='solid',label='MaPLe', markersize=10,linewidth=l)
labels = beta_weights
ax.set_xticklabels(labels, fontsize=23)

ax.set_ylabel("Top-1 average accuracy %", fontsize=26)
ax.set_xlabel("Weight scale factor β",fontsize=26)
ax.xaxis.set_label_coords(0.5, -0.18)
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=23)
plt.xticks(labels)
ax.grid(True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
plt.xlim(-3,210)
plt.legend(fontsize=23, labels=['PromptAlign', 'MaPLe+TPT'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# plt.legend(fontsize=14, labels=['Vision prompting', 'Language prompting', 'Independent V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
plt.savefig("loss_scale.png",dpi=500, bbox_inches='tight')
# plt.show()
# fig.savefig('graph_2_optional.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_1001791/2082208927.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=23)

# %% [markdown]
# ## Supplementary beta for other datasets

# %%
beta_weights = [10, 50, 100, 150, 200]
beta_dtd = np.array([45.57, 45.74, 45.75, 45.8, 45.86])
beta_cars = np.array([67.95, 68.29, 68.2, 68.25 ,68.23])
# beta_imgr = np.array([78.53, 78.96, 78.96, 79.1, 79.1])
beta_imga = np.array([58.73, 59.24, 59.37, 59.39, 59.41])
beta_ucf = np.array([69.28, 69.18, 69.1, 69.2, 69.28])
beta_caltech = np.array([93.14, 93.51, 93.5, 93.51, 93.51])
# beta_img = np.array([71.41, 71.55, 71.58, 71.59, 71.59])
maple_tpt_beta = np.mean([45.57, 66.72, 57.79, 68.94, 92.74])

beta_all = (beta_dtd + beta_cars + beta_imga + beta_ucf + beta_caltech)/5

# %%
# NOW SETTING THE TREND FOR CTX ABLATION STUDY
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig, ax = plt.subplots(figsize = (10,6), dpi=500)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(beta_weights, beta_all, marker="p",ls='dashdot',label='DTD', markersize=15,linewidth=l)
ax.plot([0], maple_tpt_beta, marker="*",ls='dashed',label='MaPLe+TPT', markersize=15,linewidth=l, color=c[2])
# ax.plot(beta_weights, beta_cars, marker="*",ls='dashed',label='StanfordCars', markersize=15,linewidth=l, color=c[2])
# ax.plot(beta_weights, beta_imgr, marker="X",ls='dashdot',label='Naive V-L prompting', markersize=15,linewidth=l)
# ax.plot(beta_weights, beta_imga,marker="v", ls='dashed',label='MaPLe', markersize=10,linewidth=l)
# ax.plot(beta_weights, beta_img, marker="1", ls='dashdot',label='MaPLe', markersize=10,linewidth=l)
labels = beta_weights
ax.set_xticklabels(labels, fontsize=23)

ax.set_ylabel("Top-1 average accuracy %", fontsize=26)
ax.set_xlabel("Weight scale factor β",fontsize=26)
# ax.xaxis.set_label_coords(0.5, -0.18)
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=23)
plt.xticks(labels)
ax.grid(True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
plt.xlim(-3,210)
plt.ylim(66,67.3)
plt.legend(fontsize=23, labels=['PromptAlign', 'MaPLe+TPT'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# plt.legend(fontsize=14, labels=['Vision prompting', 'Language prompting', 'Independent V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
plt.savefig("loss_scale_multi.png",dpi=500, bbox_inches='tight')
# plt.show()
# fig.savefig('graph_2_optional.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_3855782/2022183565.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=23)

# %% [markdown]
# ## Supplementary aumented views

# %%
n_views = [8, 16, 32, 64, 128]
imga_view = np.array([50.85, 57.61, 58.32, 59.14, 59.61])
# imgr_view = np.array([76.76, 77.93, 78.65, 78.96, 79.32])
# img_view = np.array([70.76, 70.64, 71.7, 71.57, 71.73])
cars_view = np.array([65.79, 66.93, 68, 68.2, 68.83])
dtd_view = np.array([46.81, 45.51, 45.15, 45.69, 45.92])
ucf_view = np.array([68.54, 67.78, 68.6, 69.1, 68.65])
caltech_view = np.array([93.43, 93.43, 93.79, 93.47, 93.67])
all_views = (imga_view + cars_view + dtd_view + ucf_view + caltech_view)/5

# %%
# NOW SETTING THE TREND FOR CTX ABLATION STUDY
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig = plt.figure(figsize=(10,6), dpi=500)
ax=fig.add_subplot(111)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
# c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(n_views, all_views, marker="X",ls='dashdot',label='PromptAlign', markersize=12,linewidth=l, color='#B43CC3')
# ax.plot(n_views, imgr_view, marker="*",ls='dashed',label='MaPLe+TPT', markersize=12,linewidth=l, color='#4BC33C')
# ax.plot(both_VPTP, marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
# ax.plot(compound_prompting, marker="*",ls='solid',label='MaPLe', markersize=10,linewidth=l)
labels = n_views
ax.set_xticklabels(labels, fontsize=23)
ax.set_ylabel("Top-1 average accuracy %", fontsize=26)
ax.set_xlabel("Number of augmented views",fontsize=26)
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=23)
plt.xticks(n_views)
ax.grid(True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
# plt.legend(fontsize=23, labels=['PromptAlign', 'MaPLe+TPT', 'Independent V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
plt.savefig("num_of_views_all.png",dpi=500, bbox_inches='tight')
# plt.show()
# fig.savefig('graph_2_optional.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_3855782/1490768951.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=23)

# %% [markdown]
# ## Number of Steps Suppl

# %%
n_steps = [1,2,4,6,8]
imga_steps = np.array([59.17,  61.06, 62.27, 62.69, 62.77])
# imgr_steps = np.array([78.96, 77.2, 78.2, 78.68, 79])
img_steps = np.array([70.76, 71.34, 71.7, 71.57, 71.73])
cars_steps = np.array([68.2, 67.91, 68.67, 68.74, 68.74])
dtd_steps = np.array([45.69, 45.8, 45.33, 45.27, 45.39])
ucf_teps = []
caltech_steps = []
all_steps = (imga_steps  + cars_steps + dtd_steps)/3

# %%
# NOW SETTING THE TREND FOR CTX ABLATION STUDY
# plt.figure(figsize=(10,6), tight_layout=True)#plotting
fig = plt.figure(figsize=(10,6), dpi=500)
ax=fig.add_subplot(111)
s = 9
l = 3.5
c = ["brown", "steelblue", "forestgreen", "c", "tomato", "purple", "mediumvioletred", "y"]
# c = ['red', 'green', 'orange', 'blue']
# lstyle = linestyles['densely dashdotdotted']
lstyle = "dashed"
ax.plot(n_steps, all_steps, marker="X",ls='dashdot',label='PromptAlign', markersize=12, linewidth=l, color='#4BC33C')
# ax.plot(n_steps, tpt_steps_acc, marker="X",ls='dashed',label='MaPLe+TPT', markersize=12, linewidth=l, color='#4BC33C')
# ax.plot(both_VPTP,marker="X",ls='dashdot',label='Naive V-L prompting', markersize=8,linewidth=l)
# ax.plot(compound_prompting,marker="*",ls='solid',label='MaPLe', markersize=10,linewidth=l)
labels = n_steps
ax.set_xticklabels(labels, fontsize=23)
ax.set_ylabel("Top-1 average accuracy %", fontsize=26)
ax.set_xlabel("Number of prompt update steps",fontsize=26)
ax.yaxis.set_tick_params(labelsize=9)
plt.yticks(fontsize=23)
plt.xticks(n_steps)
# plt.ylim(62.5,64)
ax.grid(True, which='major', color='gray', linestyle='-', alpha=0.5)
ax.grid(True, which='minor', color='gray', linestyle='--', alpha=0.2)
ax.minorticks_on()
# plt.legend(fontsize=23, labels=['PromptAlign', 'MaPLe+TPT', 'Independent V-L prompting', 'MaPLe'], loc='lower right', borderaxespad=0.5, handlelength=3, ncol=1)
# # It's also possible to use the reduced notation by directly setting font.family:
# plt.plot(df, 'o-', linewidth=5, linestyle='dashed')   #customization
# labels = ["1", "2",  "3", "4",  "5", "6", "8", "10","16"]
# ticks = [0, 1, 2, 3, 4, 5, 6, 7, 8]
# plt.xticks(ticks, labels,fontsize=20, weight='bold')
# plt.yticks(fontsize=20,  weight='bold')
# plt.xlabel('# Prompt tokens',fontsize=23, weight='bold')
# # plt.ylabel('Average HM (11 datasets)',fontsize=23, weight='bold')
# # # plt.title('Comparision of different variants of prompting',fontsize=23, weight='bold')
# plt.legend(fontsize=19, labels=['Base Acc.', 'New Acc.', 'H.M'])
plt.savefig("num_steps_all.png",dpi=500, bbox_inches='tight')
# plt.show()
# fig.savefig('graph_2_optional.png', dpi=250, facecolor='auto', edgecolor='auto',
#             orientation='portrait', format="png",
#             transparent=False, bbox_inches='tight',pad_inches=0.01)
# Out:
# /tmp/ipykernel_3855782/3539645335.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels, fontsize=23)
